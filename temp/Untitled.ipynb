# %%
#if
#11
x <- 5

if (x > 0) 
  {
  print("Số nguyên lớn hơn 0")
  }
else 
  {
  print("Số nguyên không lớn hơn 0")
  }


#2
x <- 10

if (x > 0 && x < 5) 
  {
  print("Số nguyên lớn hơn 0 và nhỏ hơn 5")
  }
else if (x >= 5 && x < 10) 
  {
  print("Số nguyên lớn hơn hoặc bằng 5 và nhỏ hơn 10")
  }
else 
  {
  print("Số nguyên không thỏa mãn các điều kiện trên")
}

#while
#1
i <- 1

while (i <= 5) 
  {
  print(i)
  i <- i + 1
  }

#Functions
#tên_hàm <- function(argument_1, argument_2, ...) {
## Mã thực thi của hàm
## Các xử lý và tính toán
## Kết quả trả về (nếu có)
#}


tong <- function(a, b) 
  {
  sum <- a + b
  return(sum)
}
result <- tong(3, 5)
print(result)

#cour

a <- c(8.7,6.9,8.5)
mean(a) # trung bình
sort(a) # bé - lớn
sort(a, decreasing = TRUE)  #lớn - bé
sort(a, decreasing = FALSE) #bé - lớn


#for
#1
for (i in 1:5) 
  {
  print(i)
}

#2

fruits <- c("A", "B", "C")

for (fruit in fruits) 
  {
  print(fruit)
}
1
# Out:
# Error in parse(text = x, srcfile = src): <text>:10:1: unexpected 'else'
# 9:   }
# 10: else
#     ^
# Traceback:
