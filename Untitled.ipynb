# %%
import pandas as pd

# %%
f = open(r"K:\de day\Mentor FPTU\2023\Tài liệu Văn bản Mới.txt",encoding="UTF-8")

# %%
l = []

# %%
for x in f:
    l.append(x.strip())

# %%
l
# Out:
# ['Hồ Lê Hữu Bằng',
#  'Nguyễn Đình Nguyên',
#  'Trần Đình Phúc',
#  'Trần Tuấn Kiệt',
#  'Phạm Thùy Khánh Như',
#  'Lê Viết Duy Tân',
#  'Nguyễn Ngọc Hân',
#  'Lê Đức Tài',
#  'Lê Hoàng Nam',
#  'Nguyễn Trung Dũng',
#  'Phạm Hoàng Minh Hiếu',
#  'Lê Nguyễn Đăng Khôi',
#  'Đinh Ngọc Việt',
#  'Nguyễn Phước An',
#  'Nguyễn Tiến Phát',
#  'Nguyễn Tấn Tài Lợi',
#  'Nguyễn Xuân Chi',
#  'Giang Tuấn Huy',
#  'Võ Thanh Tiến',
#  'Nguyễn Thế Hoàng Sơn',
#  'Nguyễn Quốc Tuấn',
#  'Võ Hoàng Tuấn',
#  'Nguyễn Trần Minh Khôi',
#  'Nguyễn Đoàn Mạnh Tuấn',
#  'Nguyễn Anh Thư',
#  'Vũ Lê Trường Thịnh',
#  'Mai Thiên Bảo',
#  'Nguyễn Huỳnh Tấn Phát',
#  'Nguyễn Hùng Tuấn Lâm',
#  'Nguyễn Thanh Bình',
#  'Lê Đỗ Việt Hùng',
#  'Nguyễn Nam Khoa',
#  'Trần Thụy Thủy Trúc',
#  'Trần Nguyễn Hữu Tâm',
#  'Lê Gia Huy',
#  'Trần Đặng Khánh Sơn',
#  'Đặng Khiết Anh',
#  'Nguyễn Trần Vĩnh Nghi',
#  'Phan Thành Hưng',
#  'Lê Thị Lan Phương',
#  'Cao Xuân An']

# %%
df = pd.read_csv(r"K:\de day\Mentor FPTU\2023\Danh sách đi thi - Sheet1.csv")
df
# Out:
#        Họ và Tên thí sinh  Số CMTND/Thẻ Căn cước công dân  \
# 0              Mai Duy An                       38205004203
# 1             Phạm Gia An                       91205017038
# 2     Nguyễn Khúc Thái An                       34205014674
# 3            Phạm Nhựt An                       79205045427
# 4            Ngô Thiện An                       56305002723
# ...                   ...                               ...
# 1078   Nguyễn Lê Đạo Dũng                       77205005850
# 1079     Nguyễn Minh Quân                       51205012981
# 1080    Phan Vũ Đăng Khoa                       74205004407
# 1081  Nguyễn Trần Mỹ Uyên                       82305000433
# 1082  Nguyễn Duy Nhật Tuệ                       79205003094
#
#      Tỉnh/thành phố học THPT Số báo danh
# 0                 Bình Dương    FU-60001
# 1            Tp. Hồ Chí Minh    FU-60002
# 2                   Đồng Nai    FU-60003
# 3            Tp. Hồ Chí Minh    FU-60004
# ...

# %%
df.set_index('Họ và Tên thí sinh',inplace=True)
df['Số CMTND/Thẻ Căn cước công dân'] = "0" + df['Số CMTND/Thẻ Căn cước công dân']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10932\3688370949.py in <module>
# ----> 1 df.set_index('Họ và Tên thí sinh',inplace=True)
#       2 df['Số CMTND/Thẻ Căn cước công dân'] = "0" + df['Số CMTND/Thẻ Căn cước công dân']
#
# T:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# T:\Anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Họ và Tên thí sinh'] are in the columns"

# %%
for x in l:
    for k in df.index:
        if x == k.strip():
            print(df.loc[k,'Số CMTND/Thẻ Căn cước công dân'])
# Out:
# 79205004158
# 79205025876
# 79205042820
# Họ và Tên thí sinh
# Trần Tuấn Kiệt    66205015793
# Trần Tuấn Kiệt    79205003606
# Name: Số CMTND/Thẻ Căn cước công dân, dtype: int64
# Họ và Tên thí sinh
# Trần Tuấn Kiệt    66205015793
# Trần Tuấn Kiệt    79205003606
# Name: Số CMTND/Thẻ Căn cước công dân, dtype: int64
# 77305001239
# 79205026864
# 79305011324
# 75205004599
# 79205016297
# 35205000076
# 79205012562
# Họ và Tên thí sinh
# Lê Nguyễn Đăng Khôi    80205008654
# Lê Nguyễn Đăng Khôi    79205018616
# Name: Số CMTND/Thẻ Căn cước công dân, dtype: int64
# Họ và Tên thí sinh
# Lê Nguyễn Đăng Khôi    80205008654
# Lê Nguyễn Đăng Khôi    79205018616
# Name: Số CMTND/Thẻ Căn cước công dân, dtype: int64
# 79205032001
# 80205008973
# 79205022213
# 80205008073
# 79305028493
# 75205010741
# 79205029537
# 79205010481
# 79205007031
# 79205002264
# 80205001629
# 36205009187
# 74305005358
# 79205048113
# 96205001820
# 82205000487
# 38205002716
# 77205002225
# 79205029977
# 79305001028
# ...
